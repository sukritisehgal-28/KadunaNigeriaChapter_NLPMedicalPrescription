# %%
# %pip install -qU  pandas requests beautifulsoup4 webdriver-manager selenium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Scrape diseases from Africa CDC

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import string

def scrape_africa_cdc_diseases(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Failed to retrieve {url}. Error: {e}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    disease_links = soup.find_all("div", class_="col-8 col-md-4")

    diseases = []
    for disease in disease_links:
        link = disease.find("a")
        if link:
            name = link.text.strip()
            href = link["href"]
            diseases.append((name, href))
    return diseases

africa_cdc_url = "https://africacdc.org/disease/"
africa_cdc_diseases = scrape_africa_cdc_diseases(africa_cdc_url)
diseases_df = pd.DataFrame(africa_cdc_diseases, columns=["Disease Name", "Link"])
# Print the scraped diseases
for name, link in africa_cdc_diseases:
    print(f"Disease: {name}")
    print(f"Link: {link}")
    print("-" * 50)
# Out:
# Disease: Anthrax
# Link: https://africacdc.org/disease/anthrax/
# --------------------------------------------------
# Disease: Avian Influenza
# Link: https://africacdc.org/disease/avian-influenza/
# --------------------------------------------------
# Disease: Chikungunya
# Link: https://africacdc.org/disease/chikungunya/
# --------------------------------------------------
# Disease: Cholera
# Link: https://africacdc.org/disease/cholera/
# --------------------------------------------------
# Disease: COVID-19
# Link: https://africacdc.org/disease/covid-19/
# --------------------------------------------------
# Disease: Crimean-Congo Haemorrhagic Fever
# Link: https://africacdc.org/disease/crimean-congo-haemorrhagic-fever/
# --------------------------------------------------
# Disease: Dengue Fever
# Link: https://africacdc.org/disease/dengue-fever/
# --------------------------------------------------
# Disease: Ebola Virus Disease
# Link: https://africacdc.org/disease/ebola-virus-disease/
# --------------------------------------------------
# Disease: Hepatitis B Virus (HBV)
# Link: https://africacdc.org/disease/hepatitis-b-virus-hbv/
# --------------------------------------------------
# Disease: Hepatitis C Virus
# Link: https://africacdc.org/disease/hepatitis-c-virus/
# --------------------------------------------------
# Disease: Hepatitis E Virus
# Link: https://africacdc.org/disease/hepatitis-e-virus/
# --------------------------------------------------
# Disease: HIV (Human Immunodeficiency Virus)
# Link: https://africacdc.org/disease/hiv-human-immunodeficiency-virus/
# --------------------------------------------------
# Disease: Lassa Fever
# Link: https://africacdc.org/disease/lassa-fever/
# --------------------------------------------------
# Disease: Malaria
# Link: https://africacdc.org/disease/malaria/
# --------------------------------------------------
# Disease: Marburg Virus Disease (MVD)
# Link: https://africacdc.org/disease/marburg-virus-disease-mvd/
# --------------------------------------------------
# Disease: Measles
# Link: https://africacdc.org/disease/measles/
# --------------------------------------------------
# Disease: Meningococcal Meningitis
# Link: https://africacdc.org/disease/meningococcal-meningitis/
# --------------------------------------------------
# Disease: Middle East Respiratory Syndrome
# Link: https://africacdc.org/disease/middle-east-respiratory-syndrome/
# --------------------------------------------------
# Disease: Mpox (Monkeypox)
# Link: https://africacdc.org/disease/monkeypox/
# --------------------------------------------------
# Disease: Plague
# Link: https://africacdc.org/disease/plague/
# --------------------------------------------------
# Disease: Poliomyelitis (Polio)
# Link: https://africacdc.org/disease/poliomyelitis-polio/
# --------------------------------------------------
# Disease: Rift Valley Fever
# Link: https://africacdc.org/disease/rift-valley-fever/
# --------------------------------------------------
# Disease: Tuberculosis
# Link: https://africacdc.org/disease/tuberculosis/
# --------------------------------------------------
# Disease: Yellow Fever
# Link: https://africacdc.org/disease/yellow-fever/
# --------------------------------------------------
# Disease: Zika Virus
# Link: https://africacdc.org/disease/zika-virus/
# --------------------------------------------------

# %%
diseases_df.head()
# Out:
#       Disease Name                                            Link
# 0          Anthrax          https://africacdc.org/disease/anthrax/
# 1  Avian Influenza  https://africacdc.org/disease/avian-influenza/
# 2      Chikungunya      https://africacdc.org/disease/chikungunya/
# 3          Cholera          https://africacdc.org/disease/cholera/
# 4         COVID-19         https://africacdc.org/disease/covid-19/

# %%
webmd = pd.read_csv("webmd_df.csv")

# %%
# Filtering WebMD dataset
filtered_webmd = webmd[webmd["Required"] == 1.0]

# Selecting the disease names from both DataFrames
disease_names_1 = diseases_df[['Disease Name']].rename(columns={'Disease Name': 'disease_name'})  # Standardizing name
disease_names_2 = filtered_webmd[['condition']].rename(columns={'condition': 'disease_name'})  # Standardizing name

# Ensuring both columns contain only string values
disease_names_1['disease_name'] = disease_names_1['disease_name'].astype(str)
disease_names_2['disease_name'] = disease_names_2['disease_name'].astype(str)

# Concatenating both DataFrames vertically (stacking them)
combined_disease_names = pd.concat([disease_names_1, disease_names_2], ignore_index=True)

print(combined_disease_names)  # Prints the DataFrame to the console
# Out:
#               disease_name
# 0                  Anthrax
# 1          Avian Influenza
# 2              Chikungunya
# 3                  Cholera
# 4                 COVID-19
# ..                     ...
# 57       Tuberculosis (TB)
# 58  Tuberculous Meningitis
# 59        Viral Meningitis
# 60            Yellow Fever
# 61                    Zika
#
# [62 rows x 1 columns]

# %% [markdown]
# ### Use Africa CDC Diseases as Reference for WebMd

# %%
# Define the keyword dictionary.
# The keys are the column names (for your output), and the values are lists of common words found in those sections.
keyword_dict = {
    "overview": ["overview","what is", "introduction", "background"],
    "symptoms": ["symptoms"],
    "causes": ["causes", "etiology", "risk factors","risk"],
    "diagnosis": ["diagnosis", "lab", "clinical test"],
    "treatment": ["treatment", "therapy"],
    "medication": ["medication", "prescription", "dosage", "administration"],
    "complications": ["complications"],
    "prognosis": ["prognosis", "outlook", "recovery"],
    "prevention": ["prevention", "protection"]
}

# %%
# Extract the first letter (in lowercase) for each disease
combined_disease_names['first_letter'] = combined_disease_names["disease_name"].str[0].str.lower()

# Create a dictionary mapping each letter to a list of disease names
disease_dict = combined_disease_names.groupby('first_letter')["disease_name"].apply(list).to_dict()
print("Disease dictionary:", disease_dict)
# Out:
# Disease dictionary: {'a': ['Anthrax', 'Avian Influenza', 'Arbovirus A Chikungunya Type', 'Avian Influenza (Bird Flu)'], 'b': ['Bacterial Meningitis', 'Bacterial Meningococcal Meningitis', 'Bird Flu (Avian Influenza)'], 'c': ['Chikungunya', 'Cholera', 'COVID-19', 'Crimean-Congo Haemorrhagic Fever', 'CHIK', 'Coronavirus (COVID-19)', 'Coronavirus (COVID-19), Complicaitons', 'Coronavirus (COVID-19) and Asthma', 'Coronavirus (COVID-19) and High Blood Pressure', 'Coronavirus (COVID-19) and Pregnancy', 'Coronavirus (COVID-19) in Children, Infants', 'Coronavirus (COVID-19), Recovery', 'Coronavirus (COVID-19), Symptoms', 'Coronavirus (COVID-19), Testing at Home', 'Coronavirus (COVID-19), Testing', 'COVID-19, Antibody Testing', 'Cryptococcic Meningitis'], 'd': ['Dengue Fever'], 'e': ['Ebola Virus Disease', 'Ebola', 'Epidemic Cerebrospinal Meningitis', 'Epidemic Cholera'], 'g': ['Glandular Plague'], 'h': ['Hepatitis B Virus (HBV)', 'Hepatitis C Virus', 'Hepatitis E Virus', 'HIV (Human Immunodeficiency Virus)', 'Hepatitis', 'HIV', 'Human Immunodeficiency Virus (HIV)'], 'l': ['Lassa Fever'], 'm': ['Malaria', 'Marburg Virus Disease (MVD)', 'Measles', 'Meningococcal Meningitis', 'Middle East Respiratory Syndrome', 'Mpox (Monkeypox)'], 'p': ['Plague', 'Poliomyelitis (Polio)', 'PPS (Post-Polio Syndrome)'], 'r': ['Rift Valley Fever', 'Red Measles', 'Rubella (German Measles)', 'Rubeola (Measles)'], 's': ['Spinal Meningitis'], 't': ['Tuberculosis', 'TB (Tuberculosis)', 'Torular Meningitis', 'Tuberculosis (TB)', 'Tuberculous Meningitis'], 'v': ['Viral Meningitis'], 'y': ['Yellow Fever', 'Yellow Fever'], 'z': ['Zika Virus', 'Zika']}

# %%
disease_dict
# Out:
# ['Hepatitis B Virus (HBV)',
#  'Hepatitis C Virus',
#  'Hepatitis E Virus',
#  'HIV (Human Immunodeficiency Virus)',
#  'Hepatitis',
#  'HIV',
#  'Human Immunodeficiency Virus (HIV)']

# %%
# ===============================
# STEP 2: FIND DISEASE URLs ON WEBDMD
# ===============================

DEBUG = True

# Dummy user agent and headers
user_agent = "Educational"
headers = {'User-Agent': user_agent}

# Base URL for the WebMD A-to-Z health topics page
base_url = "https://www.webmd.com/a-to-z-guides/health-topics"

# Containers for results:
found_records = []  # List of dictionaries: {"Base Disease": ..., "Disease Name": ..., "URL": ..., "Letter": ...}
not_found = []      # List of disease names (from your dictionary) that were not found on the website

# Loop only through the letters in the disease_dict
for letter, disease_list in disease_dict.items():
    url = f"{base_url}?pg={letter}"
    print(f"\nFetching URL: {url}")
    
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        print(f"Successfully fetched page for letter '{letter}' (Status Code: {response.status_code})")
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Optional debugging: Print a snippet of the page text
        snippet = soup.get_text(separator=' ', strip=True)[:200]
        print("Page text snippet:", snippet)
        
        # Find all relevant <a> tags (with href and where data-metrics-link is explicitly False)
        relevant_tags = soup.find_all('a', href=True, attrs={'data-metrics-link': False})
        
        # For each disease in the current letter group, search in the relevant links
        for disease in disease_list:
            found_any = False
            for link in relevant_tags:
                link_text = link.get_text(strip=True)
                # Check if the base disease name appears anywhere in the link text (case-insensitive)
                if disease.lower() in link_text.lower():
                    found_records.append({
                        "Base Disease": disease,
                        "Disease Name": link_text,  # the full variant as shown on the page
                        "URL": link['href'],
                        "Letter": letter
                    })
                    print(f"Found disease variant for '{disease}' on page '{letter}': {link_text} - {link['href']}")
                    found_any = True
            if not found_any:
                print(f"Disease '{disease}' not found on page '{letter}'.")
                not_found.append(disease)
    else:
        print(f"Failed to fetch URL for letter '{letter}'. Status code: {response.status_code}")

# Create a DataFrame for the found diseases
found_df = pd.DataFrame(found_records)

print("\n===== Found Diseases =====")
print(found_df)

print("\n===== Diseases Not Found =====")
print(not_found)
# Out:
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=a
# Successfully fetched page for letter 'a' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Anthrax' not found on page 'a'.
# Found disease variant for 'Avian Influenza' on page 'a': Avian Influenza (Bird Flu) - https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
# Found disease variant for 'Arbovirus A Chikungunya Type' on page 'a': Arbovirus A Chikungunya Type - https://www.webmd.com/a-to-z-guides/what-is-chikungunya
# Found disease variant for 'Avian Influenza (Bird Flu)' on page 'a': Avian Influenza (Bird Flu) - https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=b
# Successfully fetched page for letter 'b' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Bacterial Meningitis' on page 'b': Bacterial Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
# Found disease variant for 'Bacterial Meningococcal Meningitis' on page 'b': Bacterial Meningococcal Meningitis - https://www.webmd.com/children/meningococcal-meningitis-symptoms-causes-treatments-and-vaccines
# Found disease variant for 'Bird Flu (Avian Influenza)' on page 'b': Bird Flu (Avian Influenza) - https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=c
# Successfully fetched page for letter 'c' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Chikungunya' not found on page 'c'.
# Disease 'Cholera' not found on page 'c'.
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19) - https://www.webmd.com/lung/coronavirus
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19), Complicaitons - https://www.webmd.com/lung/coronavirus-complications
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19) and Asthma - https://www.webmd.com/asthma/covid-19-asthma
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19) and High Blood Pressure - https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19) and Pregnancy - https://www.webmd.com/lung/coronavirus-pregnancy
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19) in Children, Infants - https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19), Recovery - https://www.webmd.com/lung/covid-recovery-overview
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19), Symptoms - https://www.webmd.com/lung/covid-19-symptoms
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19), Testing at Home - https://www.webmd.com/lung/covid-at-home-test
# Found disease variant for 'COVID-19' on page 'c': Coronavirus (COVID-19), Testing - https://www.webmd.com/lung/coronavirus-testing
# Found disease variant for 'COVID-19' on page 'c': COVID-19, Antibody Testing - https://www.webmd.com/lung/antibody-testing-covid-19
# Disease 'Crimean-Congo Haemorrhagic Fever' not found on page 'c'.
# Found disease variant for 'CHIK' on page 'c': CHIK - https://www.webmd.com/a-to-z-guides/what-is-chikungunya
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19) - https://www.webmd.com/lung/coronavirus
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19), Complicaitons - https://www.webmd.com/lung/coronavirus-complications
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19) and Asthma - https://www.webmd.com/asthma/covid-19-asthma
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19) and High Blood Pressure - https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19) and Pregnancy - https://www.webmd.com/lung/coronavirus-pregnancy
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19) in Children, Infants - https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19), Recovery - https://www.webmd.com/lung/covid-recovery-overview
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19), Symptoms - https://www.webmd.com/lung/covid-19-symptoms
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19), Testing at Home - https://www.webmd.com/lung/covid-at-home-test
# Found disease variant for 'Coronavirus (COVID-19)' on page 'c': Coronavirus (COVID-19), Testing - https://www.webmd.com/lung/coronavirus-testing
# Found disease variant for 'Coronavirus (COVID-19), Complicaitons' on page 'c': Coronavirus (COVID-19), Complicaitons - https://www.webmd.com/lung/coronavirus-complications
# Found disease variant for 'Coronavirus (COVID-19) and Asthma' on page 'c': Coronavirus (COVID-19) and Asthma - https://www.webmd.com/asthma/covid-19-asthma
# Found disease variant for 'Coronavirus (COVID-19) and High Blood Pressure' on page 'c': Coronavirus (COVID-19) and High Blood Pressure - https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Found disease variant for 'Coronavirus (COVID-19) and Pregnancy' on page 'c': Coronavirus (COVID-19) and Pregnancy - https://www.webmd.com/lung/coronavirus-pregnancy
# Found disease variant for 'Coronavirus (COVID-19) in Children, Infants' on page 'c': Coronavirus (COVID-19) in Children, Infants - https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Found disease variant for 'Coronavirus (COVID-19), Recovery' on page 'c': Coronavirus (COVID-19), Recovery - https://www.webmd.com/lung/covid-recovery-overview
# Found disease variant for 'Coronavirus (COVID-19), Symptoms' on page 'c': Coronavirus (COVID-19), Symptoms - https://www.webmd.com/lung/covid-19-symptoms
# Found disease variant for 'Coronavirus (COVID-19), Testing at Home' on page 'c': Coronavirus (COVID-19), Testing at Home - https://www.webmd.com/lung/covid-at-home-test
# Found disease variant for 'Coronavirus (COVID-19), Testing' on page 'c': Coronavirus (COVID-19), Testing at Home - https://www.webmd.com/lung/covid-at-home-test
# Found disease variant for 'Coronavirus (COVID-19), Testing' on page 'c': Coronavirus (COVID-19), Testing - https://www.webmd.com/lung/coronavirus-testing
# Found disease variant for 'COVID-19, Antibody Testing' on page 'c': COVID-19, Antibody Testing - https://www.webmd.com/lung/antibody-testing-covid-19
# Found disease variant for 'Cryptococcic Meningitis' on page 'c': Cryptococcic Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=d
# Successfully fetched page for letter 'd' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Dengue Fever' not found on page 'd'.
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=e
# Successfully fetched page for letter 'e' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Ebola Virus Disease' not found on page 'e'.
# Found disease variant for 'Ebola' on page 'e': Ebola - https://www.webmd.com/a-to-z-guides/ebola-fever-virus-infection
# Found disease variant for 'Epidemic Cerebrospinal Meningitis' on page 'e': Epidemic Cerebrospinal Meningitis - https://www.webmd.com/children/meningococcal-meningitis-symptoms-causes-treatments-and-vaccines
# Found disease variant for 'Epidemic Cholera' on page 'e': Epidemic Cholera - https://www.webmd.com/a-to-z-guides/cholera-faq
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=g
# Successfully fetched page for letter 'g' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Glandular Plague' on page 'g': Glandular Plague - https://www.webmd.com/a-to-z-guides/plague-faq
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=h
# Successfully fetched page for letter 'h' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Hepatitis B Virus (HBV)' not found on page 'h'.
# Disease 'Hepatitis C Virus' not found on page 'h'.
# Disease 'Hepatitis E Virus' not found on page 'h'.
# Disease 'HIV (Human Immunodeficiency Virus)' not found on page 'h'.
# Found disease variant for 'Hepatitis' on page 'h': Hepatitis - https://www.webmd.com/hepatitis/default.htm
# Found disease variant for 'HIV' on page 'h': HIV - https://www.webmd.com/hiv-aids/default.htm
# Found disease variant for 'HIV' on page 'h': Hives - https://www.webmd.com/skin-problems-and-treatments/guide/hives-urticaria-angioedema
# Found disease variant for 'HIV' on page 'h': Human Immunodeficiency Virus (HIV) - https://www.webmd.com/hiv-aids/default.htm
# Found disease variant for 'Human Immunodeficiency Virus (HIV)' on page 'h': Human Immunodeficiency Virus (HIV) - https://www.webmd.com/hiv-aids/default.htm
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=l
# Successfully fetched page for letter 'l' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Lassa Fever' not found on page 'l'.
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=m
# Successfully fetched page for letter 'm' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Malaria' not found on page 'm'.
# Disease 'Marburg Virus Disease (MVD)' not found on page 'm'.
# Disease 'Measles' not found on page 'm'.
# Disease 'Meningococcal Meningitis' not found on page 'm'.
# Disease 'Middle East Respiratory Syndrome' not found on page 'm'.
# Disease 'Mpox (Monkeypox)' not found on page 'm'.
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=p
# Successfully fetched page for letter 'p' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Plague' not found on page 'p'.
# Disease 'Poliomyelitis (Polio)' not found on page 'p'.
# Found disease variant for 'PPS (Post-Polio Syndrome)' on page 'p': PPS (Post-Polio Syndrome) - https://www.webmd.com/children/vaccines/polio-vaccine-ipv
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=r
# Successfully fetched page for letter 'r' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Rift Valley Fever' not found on page 'r'.
# Found disease variant for 'Red Measles' on page 'r': Red Measles - https://www.webmd.com/children/vaccines/what-is-measles
# Found disease variant for 'Rubella (German Measles)' on page 'r': Rubella (German Measles) - https://www.webmd.com/a-to-z-guides/what-is-rubella
# Found disease variant for 'Rubeola (Measles)' on page 'r': Rubeola (Measles) - https://www.webmd.com/children/vaccines/what-is-measles
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=s
# Successfully fetched page for letter 's' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Spinal Meningitis' on page 's': Spinal Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=t
# Successfully fetched page for letter 't' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Tuberculosis' on page 't': TB (Tuberculosis) - https://www.webmd.com/lung/understanding-tuberculosis-basics
# Found disease variant for 'Tuberculosis' on page 't': Tuberculosis (TB) - https://www.webmd.com/lung/understanding-tuberculosis-basics
# Found disease variant for 'TB (Tuberculosis)' on page 't': TB (Tuberculosis) - https://www.webmd.com/lung/understanding-tuberculosis-basics
# Found disease variant for 'Torular Meningitis' on page 't': Torular Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
# Found disease variant for 'Tuberculosis (TB)' on page 't': Tuberculosis (TB) - https://www.webmd.com/lung/understanding-tuberculosis-basics
# Found disease variant for 'Tuberculous Meningitis' on page 't': Tuberculous Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=v
# Successfully fetched page for letter 'v' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Viral Meningitis' on page 'v': Viral Meningitis - https://www.webmd.com/children/understanding-meningitis-basics
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=y
# Successfully fetched page for letter 'y' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Found disease variant for 'Yellow Fever' on page 'y': Yellow Fever - https://www.webmd.com/a-to-z-guides/yellow-fever-symptoms-treatment
# Found disease variant for 'Yellow Fever' on page 'y': Yellow Fever - https://www.webmd.com/a-to-z-guides/yellow-fever-symptoms-treatment
#
# Fetching URL: https://www.webmd.com/a-to-z-guides/health-topics?pg=z
# Successfully fetched page for letter 'z' (Status Code: 200)
# Page text snippet: All Health Topics Skip to main content Home Conditions Back Conditions View All ADD/ADHD Allergies Arthritis Atrial fibrillation Breast Cancer Cancer Crohn's Disease Depression Diabetes DVT Eczema Eye
# Disease 'Zika Virus' not found on page 'z'.
# Found disease variant for 'Zika' on page 'z': Zika - https://www.webmd.com/a-to-z-guides/zika-virus-symptoms-prevention
#
# ===== Found Diseases =====
#                           Base Disease                        Disease Name  \
# 0                      Avian Influenza          Avian Influenza (Bird Flu)
# 1         Arbovirus A Chikungunya Type        Arbovirus A Chikungunya Type
# 2           Avian Influenza (Bird Flu)          Avian Influenza (Bird Flu)
# 3                 Bacterial Meningitis                Bacterial Meningitis
# 4   Bacterial Meningococcal Meningitis  Bacterial Meningococcal Meningitis
# ..                                 ...                                 ...
# 59              Tuberculous Meningitis              Tuberculous Meningitis
# 60                    Viral Meningitis                    Viral Meningitis
# 61                        Yellow Fever                        Yellow Fever
# 62                        Yellow Fever                        Yellow Fever
# 63                                Zika                                Zika
#
#                                                   URL Letter
# 0   https://www.webmd.com/cold-and-flu/flu-guide/w...      a
# 1   https://www.webmd.com/a-to-z-guides/what-is-ch...      a
# 2   https://www.webmd.com/cold-and-flu/flu-guide/w...      a
# 3   https://www.webmd.com/children/understanding-m...      b
# 4   https://www.webmd.com/children/meningococcal-m...      b
# ..                                                ...    ...
# 59  https://www.webmd.com/children/understanding-m...      t
# 60  https://www.webmd.com/children/understanding-m...      v
# 61  https://www.webmd.com/a-to-z-guides/yellow-fev...      y
# 62  https://www.webmd.com/a-to-z-guides/yellow-fev...      y
# 63  https://www.webmd.com/a-to-z-guides/zika-virus...      z
#
# [64 rows x 4 columns]
#
# ===== Diseases Not Found =====
# ['Anthrax', 'Chikungunya', 'Cholera', 'Crimean-Congo Haemorrhagic Fever', 'Dengue Fever', 'Ebola Virus Disease', 'Hepatitis B Virus (HBV)', 'Hepatitis C Virus', 'Hepatitis E Virus', 'HIV (Human Immunodeficiency Virus)', 'Lassa Fever', 'Malaria', 'Marburg Virus Disease (MVD)', 'Measles', 'Meningococcal Meningitis', 'Middle East Respiratory Syndrome', 'Mpox (Monkeypox)', 'Plague', 'Poliomyelitis (Polio)', 'Rift Valley Fever', 'Zika Virus']

# %%
found_df
# Out:
#                           Base Disease                        Disease Name  \
# 0                      Avian Influenza          Avian Influenza (Bird Flu)
# 1         Arbovirus A Chikungunya Type        Arbovirus A Chikungunya Type
# 2           Avian Influenza (Bird Flu)          Avian Influenza (Bird Flu)
# 3                 Bacterial Meningitis                Bacterial Meningitis
# 4   Bacterial Meningococcal Meningitis  Bacterial Meningococcal Meningitis
# ..                                 ...                                 ...
# 59              Tuberculous Meningitis              Tuberculous Meningitis
# 60                    Viral Meningitis                    Viral Meningitis
# 61                        Yellow Fever                        Yellow Fever
# 62                        Yellow Fever                        Yellow Fever
# 63                                Zika                                Zika
#
#                                                   URL Letter
# 0   https://www.webmd.com/cold-and-flu/flu-guide/w...      a
# 1   https://www.webmd.com/a-to-z-guides/what-is-ch...      a
# 2   https://www.webmd.com/cold-and-flu/flu-guide/w...      a
# 3   https://www.webmd.com/children/understanding-m...      b
# 4   https://www.webmd.com/children/meningococcal-m...      b
# ..                                                ...    ...
# 59  https://www.webmd.com/children/understanding-m...      t
# 60  https://www.webmd.com/children/understanding-m...      v
# 61  https://www.webmd.com/a-to-z-guides/yellow-fev...      y
# 62  https://www.webmd.com/a-to-z-guides/yellow-fev...      y
# 63  https://www.webmd.com/a-to-z-guides/zika-virus...      z
#
# [64 rows x 4 columns]

# %%
found_df.columns
# Out:
# Index(['Base Disease', 'Disease Name', 'URL', 'Letter'], dtype='object')

# %%
found_df[found_df["Letter"]=="h"]
# Out:
#                           Base Disease                        Disease Name  \
# 44                           Hepatitis                           Hepatitis
# 45                                 HIV                                 HIV
# 46                                 HIV                               Hives
# 47                                 HIV  Human Immunodeficiency Virus (HIV)
# 48  Human Immunodeficiency Virus (HIV)  Human Immunodeficiency Virus (HIV)
#
#                                                   URL Letter
# 44        https://www.webmd.com/hepatitis/default.htm      h
# 45         https://www.webmd.com/hiv-aids/default.htm      h
# 46  https://www.webmd.com/skin-problems-and-treatm...      h
# 47         https://www.webmd.com/hiv-aids/default.htm      h
# 48         https://www.webmd.com/hiv-aids/default.htm      h

# %%
not_found
# Out:
# ['Anthrax',
#  'Chikungunya',
#  'Cholera',
#  'Crimean-Congo Haemorrhagic Fever',
#  'Dengue Fever',
#  'Ebola Virus Disease',
#  'Hepatitis B Virus (HBV)',
#  'Hepatitis C Virus',
#  'Hepatitis E Virus',
#  'HIV (Human Immunodeficiency Virus)',
#  'Lassa Fever',
#  'Malaria',
#  'Marburg Virus Disease (MVD)',
#  'Measles',
#  'Meningococcal Meningitis',
#  'Middle East Respiratory Syndrome',
#  'Mpox (Monkeypox)',
#  'Plague',
#  'Poliomyelitis (Polio)',
#  'Rift Valley Fever',
#  'Zika Virus']

# %%
def extract_section_text(soup, keywords):
    """
    Look for header tags (h1 to h6) that contain any of the keywords in the given list.
    Gather text from the following siblings until the next header.
    Returns a single text string (concatenated content) for each category.
    """
    content_list = []

    for header in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']):
        header_text = header.get_text().strip().lower()
        if any(keyword in header_text for keyword in keywords):
            temp_content = []
            
            for sibling in header.find_next_siblings():
                if sibling.name and sibling.name.startswith('h'):
                    break  # Stop at the next section header

                if sibling.name in ['p', 'div', 'ul', 'li', 'span']:
                    text = sibling.get_text(separator=' ', strip=True)
                    if text:
                        temp_content.append(text)

            # Merge extracted text into a single string
            section_text = ' '.join(temp_content)
            if section_text:
                content_list.append(section_text)

    # Return a single merged text block for this section
    return ' '.join(content_list) if content_list else ''

# %%
# Example container for detailed results:
disease_data_list = []  # List of dictionaries with unified columns for each disease
invalid_links = []      # List of disease names with invalid or error pages

# Process each disease from found_df (assuming found_df has been created from your Step 2 code)
for idx, row in found_df.iterrows():
# for idx, row in tuber.iterrows():
    disease_name = row["Disease Name"]
    url = row["URL"]
    print(f"\nProcessing '{disease_name}' with URL: {url}")
    
    try:
        response = requests.get(url, headers=headers)
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        invalid_links.append(disease_name)
        continue

    if response.status_code != 200:
        print(f"Link for '{disease_name}' returned status code {response.status_code}.")
        invalid_links.append(disease_name)
        continue
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # For debugging: print a snippet of the page text
    page_text = soup.get_text(separator=' ', strip=True).lower()
    print(f"Page text for '{disease_name}' (first 500 characters):\n{page_text[:500]}\n")
    
    # Initialize a record for this disease
    disease_record = {"Disease Name": disease_name, "URL": url}

    # Extract sections for each category
    for column, keywords in keyword_dict.items():
        extracted_text = extract_section_text(soup, keywords)
        
        # Store only one combined text block per section
        disease_record[column] = extracted_text

    # Add to the data list
    disease_data_list.append(disease_record)
    print(f"Finished processing '{disease_name}'.")

# Create a unified DataFrame with one row per disease
disease_details_df = pd.DataFrame(disease_data_list)

print("\n===== Extracted Disease Details =====")
print(disease_details_df.head())

print("\n===== Diseases with Invalid or Non-Working Links =====")
print(invalid_links)
# Out:
# Processing 'Avian Influenza (Bird Flu)' with URL: https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
# Page text for 'Avian Influenza (Bird Flu)' (first 500 characters):
# bird flu (avian influenza): causes, symptoms, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements b
#
# Finished processing 'Avian Influenza (Bird Flu)'.
#
# Processing 'Arbovirus A Chikungunya Type' with URL: https://www.webmd.com/a-to-z-guides/what-is-chikungunya
# Page text for 'Arbovirus A Chikungunya Type' (first 500 characters):
# chikungunya: transmission, treatment, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'Arbovirus A Chikungunya Type'.
#
# Processing 'Avian Influenza (Bird Flu)' with URL: https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
# Page text for 'Avian Influenza (Bird Flu)' (first 500 characters):
# bird flu (avian influenza): causes, symptoms, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements b
#
# Finished processing 'Avian Influenza (Bird Flu)'.
#
# Processing 'Bacterial Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Bacterial Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Bacterial Meningitis'.
#
# Processing 'Bacterial Meningococcal Meningitis' with URL: https://www.webmd.com/children/meningococcal-meningitis-symptoms-causes-treatments-and-vaccines
# Page text for 'Bacterial Meningococcal Meningitis' (first 500 characters):
# meningococcal meningitis: symptoms, causes, treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back d
#
# Finished processing 'Bacterial Meningococcal Meningitis'.
#
# Processing 'Bird Flu (Avian Influenza)' with URL: https://www.webmd.com/cold-and-flu/flu-guide/what-know-about-bird-flu
# Page text for 'Bird Flu (Avian Influenza)' (first 500 characters):
# bird flu (avian influenza): causes, symptoms, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements b
#
# Finished processing 'Bird Flu (Avian Influenza)'.
#
# Processing 'Coronavirus (COVID-19)' with URL: https://www.webmd.com/lung/coronavirus
# Link for 'Coronavirus (COVID-19)' returned status code 404.
#
# Processing 'Coronavirus (COVID-19), Complicaitons' with URL: https://www.webmd.com/lung/coronavirus-complications
# Page text for 'Coronavirus (COVID-19), Complicaitons' (first 500 characters):
# what are the complications of coronavirus (covid-19)? skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dr
#
# Finished processing 'Coronavirus (COVID-19), Complicaitons'.
#
# Processing 'Coronavirus (COVID-19) and Asthma' with URL: https://www.webmd.com/asthma/covid-19-asthma
# Page text for 'Coronavirus (COVID-19) and Asthma' (first 500 characters):
# asthma and coronavirus: how to prepare and when to call a doctor skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppleme
#
# Finished processing 'Coronavirus (COVID-19) and Asthma'.
#
# Processing 'Coronavirus (COVID-19) and High Blood Pressure' with URL: https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Page text for 'Coronavirus (COVID-19) and High Blood Pressure' (first 500 characters):
# high blood pressure & coronavirus (higher-risk people): symptoms, complications, treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative coliti
#
# Finished processing 'Coronavirus (COVID-19) and High Blood Pressure'.
#
# Processing 'Coronavirus (COVID-19) and Pregnancy' with URL: https://www.webmd.com/lung/coronavirus-pregnancy
# Page text for 'Coronavirus (COVID-19) and Pregnancy' (first 500 characters):
# coronavirus and pregnancy: what you should know skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs &
#
# Finished processing 'Coronavirus (COVID-19) and Pregnancy'.
#
# Processing 'Coronavirus (COVID-19) in Children, Infants' with URL: https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Page text for 'Coronavirus (COVID-19) in Children, Infants' (first 500 characters):
# coronavirus in kids and babies: risks, symptoms, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplemen
#
# Finished processing 'Coronavirus (COVID-19) in Children, Infants'.
#
# Processing 'Coronavirus (COVID-19), Recovery' with URL: https://www.webmd.com/lung/covid-recovery-overview
# Page text for 'Coronavirus (COVID-19), Recovery' (first 500 characters):
# coronavirus recovery: rate, time, & outlook skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supp
#
# Finished processing 'Coronavirus (COVID-19), Recovery'.
#
# Processing 'Coronavirus (COVID-19), Symptoms' with URL: https://www.webmd.com/lung/covid-19-symptoms
# Page text for 'Coronavirus (COVID-19), Symptoms' (first 500 characters):
# coronavirus symptoms: early signs, serious symptoms skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drug
#
# Finished processing 'Coronavirus (COVID-19), Symptoms'.
#
# Processing 'Coronavirus (COVID-19), Testing at Home' with URL: https://www.webmd.com/lung/covid-at-home-test
# Page text for 'Coronavirus (COVID-19), Testing at Home' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing at Home'.
#
# Processing 'Coronavirus (COVID-19), Testing' with URL: https://www.webmd.com/lung/coronavirus-testing
# Page text for 'Coronavirus (COVID-19), Testing' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing'.
#
# Processing 'COVID-19, Antibody Testing' with URL: https://www.webmd.com/lung/antibody-testing-covid-19
# Page text for 'COVID-19, Antibody Testing' (first 500 characters):
# coronavirus (covid-19) antibody tests: how it works & how to get one skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supp
#
# Finished processing 'COVID-19, Antibody Testing'.
#
# Processing 'CHIK' with URL: https://www.webmd.com/a-to-z-guides/what-is-chikungunya
# Page text for 'CHIK' (first 500 characters):
# chikungunya: transmission, treatment, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'CHIK'.
#
# Processing 'Coronavirus (COVID-19)' with URL: https://www.webmd.com/lung/coronavirus
# Link for 'Coronavirus (COVID-19)' returned status code 404.
#
# Processing 'Coronavirus (COVID-19), Complicaitons' with URL: https://www.webmd.com/lung/coronavirus-complications
# Page text for 'Coronavirus (COVID-19), Complicaitons' (first 500 characters):
# what are the complications of coronavirus (covid-19)? skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dr
#
# Finished processing 'Coronavirus (COVID-19), Complicaitons'.
#
# Processing 'Coronavirus (COVID-19) and Asthma' with URL: https://www.webmd.com/asthma/covid-19-asthma
# Page text for 'Coronavirus (COVID-19) and Asthma' (first 500 characters):
# asthma and coronavirus: how to prepare and when to call a doctor skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppleme
#
# Finished processing 'Coronavirus (COVID-19) and Asthma'.
#
# Processing 'Coronavirus (COVID-19) and High Blood Pressure' with URL: https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Page text for 'Coronavirus (COVID-19) and High Blood Pressure' (first 500 characters):
# high blood pressure & coronavirus (higher-risk people): symptoms, complications, treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative coliti
#
# Finished processing 'Coronavirus (COVID-19) and High Blood Pressure'.
#
# Processing 'Coronavirus (COVID-19) and Pregnancy' with URL: https://www.webmd.com/lung/coronavirus-pregnancy
# Page text for 'Coronavirus (COVID-19) and Pregnancy' (first 500 characters):
# coronavirus and pregnancy: what you should know skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs &
#
# Finished processing 'Coronavirus (COVID-19) and Pregnancy'.
#
# Processing 'Coronavirus (COVID-19) in Children, Infants' with URL: https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Page text for 'Coronavirus (COVID-19) in Children, Infants' (first 500 characters):
# coronavirus in kids and babies: risks, symptoms, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplemen
#
# Finished processing 'Coronavirus (COVID-19) in Children, Infants'.
#
# Processing 'Coronavirus (COVID-19), Recovery' with URL: https://www.webmd.com/lung/covid-recovery-overview
# Page text for 'Coronavirus (COVID-19), Recovery' (first 500 characters):
# coronavirus recovery: rate, time, & outlook skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supp
#
# Finished processing 'Coronavirus (COVID-19), Recovery'.
#
# Processing 'Coronavirus (COVID-19), Symptoms' with URL: https://www.webmd.com/lung/covid-19-symptoms
# Page text for 'Coronavirus (COVID-19), Symptoms' (first 500 characters):
# coronavirus symptoms: early signs, serious symptoms skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drug
#
# Finished processing 'Coronavirus (COVID-19), Symptoms'.
#
# Processing 'Coronavirus (COVID-19), Testing at Home' with URL: https://www.webmd.com/lung/covid-at-home-test
# Page text for 'Coronavirus (COVID-19), Testing at Home' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing at Home'.
#
# Processing 'Coronavirus (COVID-19), Testing' with URL: https://www.webmd.com/lung/coronavirus-testing
# Page text for 'Coronavirus (COVID-19), Testing' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing'.
#
# Processing 'Coronavirus (COVID-19), Complicaitons' with URL: https://www.webmd.com/lung/coronavirus-complications
# Page text for 'Coronavirus (COVID-19), Complicaitons' (first 500 characters):
# what are the complications of coronavirus (covid-19)? skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dr
#
# Finished processing 'Coronavirus (COVID-19), Complicaitons'.
#
# Processing 'Coronavirus (COVID-19) and Asthma' with URL: https://www.webmd.com/asthma/covid-19-asthma
# Page text for 'Coronavirus (COVID-19) and Asthma' (first 500 characters):
# asthma and coronavirus: how to prepare and when to call a doctor skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppleme
#
# Finished processing 'Coronavirus (COVID-19) and Asthma'.
#
# Processing 'Coronavirus (COVID-19) and High Blood Pressure' with URL: https://www.webmd.com/lung/coronavirus-high-blood-pressure
# Page text for 'Coronavirus (COVID-19) and High Blood Pressure' (first 500 characters):
# high blood pressure & coronavirus (higher-risk people): symptoms, complications, treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative coliti
#
# Finished processing 'Coronavirus (COVID-19) and High Blood Pressure'.
#
# Processing 'Coronavirus (COVID-19) and Pregnancy' with URL: https://www.webmd.com/lung/coronavirus-pregnancy
# Page text for 'Coronavirus (COVID-19) and Pregnancy' (first 500 characters):
# coronavirus and pregnancy: what you should know skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs &
#
# Finished processing 'Coronavirus (COVID-19) and Pregnancy'.
#
# Processing 'Coronavirus (COVID-19) in Children, Infants' with URL: https://www.webmd.com/lung/coronavirus-covid-19-babies-children
# Page text for 'Coronavirus (COVID-19) in Children, Infants' (first 500 characters):
# coronavirus in kids and babies: risks, symptoms, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplemen
#
# Finished processing 'Coronavirus (COVID-19) in Children, Infants'.
#
# Processing 'Coronavirus (COVID-19), Recovery' with URL: https://www.webmd.com/lung/covid-recovery-overview
# Page text for 'Coronavirus (COVID-19), Recovery' (first 500 characters):
# coronavirus recovery: rate, time, & outlook skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supp
#
# Finished processing 'Coronavirus (COVID-19), Recovery'.
#
# Processing 'Coronavirus (COVID-19), Symptoms' with URL: https://www.webmd.com/lung/covid-19-symptoms
# Page text for 'Coronavirus (COVID-19), Symptoms' (first 500 characters):
# coronavirus symptoms: early signs, serious symptoms skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drug
#
# Finished processing 'Coronavirus (COVID-19), Symptoms'.
#
# Processing 'Coronavirus (COVID-19), Testing at Home' with URL: https://www.webmd.com/lung/covid-at-home-test
# Page text for 'Coronavirus (COVID-19), Testing at Home' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing at Home'.
#
# Processing 'Coronavirus (COVID-19), Testing at Home' with URL: https://www.webmd.com/lung/covid-at-home-test
# Page text for 'Coronavirus (COVID-19), Testing at Home' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing at Home'.
#
# Processing 'Coronavirus (COVID-19), Testing' with URL: https://www.webmd.com/lung/coronavirus-testing
# Page text for 'Coronavirus (COVID-19), Testing' (first 500 characters):
# coronavirus (covid-19) testing skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs
#
# Finished processing 'Coronavirus (COVID-19), Testing'.
#
# Processing 'COVID-19, Antibody Testing' with URL: https://www.webmd.com/lung/antibody-testing-covid-19
# Page text for 'COVID-19, Antibody Testing' (first 500 characters):
# coronavirus (covid-19) antibody tests: how it works & how to get one skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supp
#
# Finished processing 'COVID-19, Antibody Testing'.
#
# Processing 'Cryptococcic Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Cryptococcic Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Cryptococcic Meningitis'.
#
# Processing 'Ebola' with URL: https://www.webmd.com/a-to-z-guides/ebola-fever-virus-infection
# Page text for 'Ebola' (first 500 characters):
# ebola virus disease skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements drugs supplement
#
# Finished processing 'Ebola'.
#
# Processing 'Epidemic Cerebrospinal Meningitis' with URL: https://www.webmd.com/children/meningococcal-meningitis-symptoms-causes-treatments-and-vaccines
# Page text for 'Epidemic Cerebrospinal Meningitis' (first 500 characters):
# meningococcal meningitis: symptoms, causes, treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back d
#
# Finished processing 'Epidemic Cerebrospinal Meningitis'.
#
# Processing 'Epidemic Cholera' with URL: https://www.webmd.com/a-to-z-guides/cholera-faq
# Page text for 'Epidemic Cholera' (first 500 characters):
# cholera: causes, symptoms, treatment, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'Epidemic Cholera'.
#
# Processing 'Glandular Plague' with URL: https://www.webmd.com/a-to-z-guides/plague-faq
# Page text for 'Glandular Plague' (first 500 characters):
# plague: overview, symptoms, and types (bubonic, septicemic and pneumonic) skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs &
#
# Finished processing 'Glandular Plague'.
#
# Processing 'Hepatitis' with URL: https://www.webmd.com/hepatitis/default.htm
# Page text for 'Hepatitis' (first 500 characters):
# hepatitis a, b, and c center: symptoms, causes, tests, transmission, and treatments skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view a
#
# Finished processing 'Hepatitis'.
#
# Processing 'HIV' with URL: https://www.webmd.com/hiv-aids/default.htm
# Page text for 'HIV' (first 500 characters):
# aids and hiv health center - webmd skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements d
#
# Finished processing 'HIV'.
#
# Processing 'Hives' with URL: https://www.webmd.com/skin-problems-and-treatments/guide/hives-urticaria-angioedema
# Page text for 'Hives' (first 500 characters):
# hives - symptoms, causes, & treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplement
#
# Finished processing 'Hives'.
#
# Processing 'Human Immunodeficiency Virus (HIV)' with URL: https://www.webmd.com/hiv-aids/default.htm
# Page text for 'Human Immunodeficiency Virus (HIV)' (first 500 characters):
# aids and hiv health center - webmd skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements d
#
# Finished processing 'Human Immunodeficiency Virus (HIV)'.
#
# Processing 'Human Immunodeficiency Virus (HIV)' with URL: https://www.webmd.com/hiv-aids/default.htm
# Page text for 'Human Immunodeficiency Virus (HIV)' (first 500 characters):
# aids and hiv health center - webmd skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements d
#
# Finished processing 'Human Immunodeficiency Virus (HIV)'.
#
# Processing 'PPS (Post-Polio Syndrome)' with URL: https://www.webmd.com/children/vaccines/polio-vaccine-ipv
# Page text for 'PPS (Post-Polio Syndrome)' (first 500 characters):
# polio vaccine (ipv): purpose, risks, benefits skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & su
#
# Finished processing 'PPS (Post-Polio Syndrome)'.
#
# Processing 'Red Measles' with URL: https://www.webmd.com/children/vaccines/what-is-measles
# Page text for 'Red Measles' (first 500 characters):
# measles virus (rubeola): symptoms, causes, treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'Red Measles'.
#
# Processing 'Rubella (German Measles)' with URL: https://www.webmd.com/a-to-z-guides/what-is-rubella
# Page text for 'Rubella (German Measles)' (first 500 characters):
# rubella (german measles): symptoms, causes, treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dr
#
# Finished processing 'Rubella (German Measles)'.
#
# Processing 'Rubeola (Measles)' with URL: https://www.webmd.com/children/vaccines/what-is-measles
# Page text for 'Rubeola (Measles)' (first 500 characters):
# measles virus (rubeola): symptoms, causes, treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'Rubeola (Measles)'.
#
# Processing 'Spinal Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Spinal Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Spinal Meningitis'.
#
# Processing 'TB (Tuberculosis)' with URL: https://www.webmd.com/lung/understanding-tuberculosis-basics
# Page text for 'TB (Tuberculosis)' (first 500 characters):
# understanding tuberculosis: causes, symptoms, and treatment options skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppl
#
# Finished processing 'TB (Tuberculosis)'.
#
# Processing 'Tuberculosis (TB)' with URL: https://www.webmd.com/lung/understanding-tuberculosis-basics
# Page text for 'Tuberculosis (TB)' (first 500 characters):
# understanding tuberculosis: causes, symptoms, and treatment options skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppl
#
# Finished processing 'Tuberculosis (TB)'.
#
# Processing 'TB (Tuberculosis)' with URL: https://www.webmd.com/lung/understanding-tuberculosis-basics
# Page text for 'TB (Tuberculosis)' (first 500 characters):
# understanding tuberculosis: causes, symptoms, and treatment options skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppl
#
# Finished processing 'TB (Tuberculosis)'.
#
# Processing 'Torular Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Torular Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Torular Meningitis'.
#
# Processing 'Tuberculosis (TB)' with URL: https://www.webmd.com/lung/understanding-tuberculosis-basics
# Page text for 'Tuberculosis (TB)' (first 500 characters):
# understanding tuberculosis: causes, symptoms, and treatment options skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & suppl
#
# Finished processing 'Tuberculosis (TB)'.
#
# Processing 'Tuberculous Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Tuberculous Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Tuberculous Meningitis'.
#
# Processing 'Viral Meningitis' with URL: https://www.webmd.com/children/understanding-meningitis-basics
# Page text for 'Viral Meningitis' (first 500 characters):
# meningitis: symptoms, causes, transmission, and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements bac
#
# Finished processing 'Viral Meningitis'.
#
# Processing 'Yellow Fever' with URL: https://www.webmd.com/a-to-z-guides/yellow-fever-symptoms-treatment
# Page text for 'Yellow Fever' (first 500 characters):
# yellow fever: symptoms and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements
#
# Finished processing 'Yellow Fever'.
#
# Processing 'Yellow Fever' with URL: https://www.webmd.com/a-to-z-guides/yellow-fever-symptoms-treatment
# Page text for 'Yellow Fever' (first 500 characters):
# yellow fever: symptoms and treatment skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back drugs & supplements
#
# Finished processing 'Yellow Fever'.
#
# Processing 'Zika' with URL: https://www.webmd.com/a-to-z-guides/zika-virus-symptoms-prevention
# Page text for 'Zika' (first 500 characters):
# zika virus symptoms, countries, risk, and prevention skip to main content home conditions back conditions view all add/adhd allergies arthritis atrial fibrillation breast cancer cancer crohn's disease depression diabetes dvt eczema eye health heart disease hiv & aids lung disease lupus mental health multiple sclerosis migraine pain management psoriasis psoriatic arthritis rheumatoid arthritis sexual conditions skin problems sleep disorders ulcerative colitis view all drugs & supplements back dru
#
# Finished processing 'Zika'.
#
# ===== Extracted Disease Details =====
#                          Disease Name  \
# 0          Avian Influenza (Bird Flu)
# 1        Arbovirus A Chikungunya Type
# 2          Avian Influenza (Bird Flu)
# 3                Bacterial Meningitis
# 4  Bacterial Meningococcal Meningitis
#
#                                                  URL  \
# 0  https://www.webmd.com/cold-and-flu/flu-guide/w...
# 1  https://www.webmd.com/a-to-z-guides/what-is-ch...
# 2  https://www.webmd.com/cold-and-flu/flu-guide/w...
# 3  https://www.webmd.com/children/understanding-m...
# 4  https://www.webmd.com/children/meningococcal-m...
#
#                                             overview  \
# 0  Bird flu, also called avian influenza, is a vi...
# 1
# 2  Bird flu, also called avian influenza, is a vi...
# 3  Meningitis is a rare infection that affects th...
# 4
#
#                                             symptoms  \
# 0  Symptoms of bird flu show up differently in bi...
# 1
# 2  Symptoms of bird flu show up differently in bi...
# 3  Meningitis can cause a rash that starts small ...
# 4  A meningococcal infection can get worse very q...
#
#                                               causes  \
# 0  Bird flu is caused by influenza A viruses. How...
# 1  If you’re going to a place that has an outbrea...
# 2  Bird flu is caused by influenza A viruses. How...
# 3  Anyone can get meningitis, but research shows ...
# 4  Neisseria meningitidis, also called meningococ...
#
#                                            diagnosis  \
# 0  Doctors can’t diagnose bird flu just by your s...
# 1
# 2  Doctors can’t diagnose bird flu just by your s...
# 3  Your doctor will ask about your medical histor...
# 4  If they suspect meningococcal meningitis, doct...
#
#                                            treatment medication  \
# 0  If you see a doctor early in your infection, t...
# 1
# 2  If you see a doctor early in your infection, t...
# 3  Your treatment will depend on the type of meni...
# 4  The treatment for meningococcal meningitis is ...
#
#                                        complications  \
# 0  It’s possible that bird flu may cause further ...
# 1
# 2  It’s possible that bird flu may cause further ...
# 3  Meningitis can cause severe complications in a...
# 4  Meningococcal meningitis can cause death or se...
#
#                                            prognosis  \
# 0
# 1  Most people don't die from the virus. In fact,...
# 2
# 3
# 4
#
#                                           prevention
# 0  Your chances of getting bird flu are very low....
# 1
# 2  Your chances of getting bird flu are very low....
# 3  You may be able to prevent meningitis by avoid...
# 4
#
# ===== Diseases with Invalid or Non-Working Links =====
# ['Coronavirus (COVID-19)', 'Coronavirus (COVID-19)']

# %%
# ===============================
# OUTPUT RESULTS
# ===============================

print("\n===== Extracted Disease Details =====")
print(disease_details_df.head())

print("\n===== Diseases with Invalid or Non-Working Links =====")
print(invalid_links)

# Save results to CSV and JSON formats
disease_details_df.to_csv("disease_details.csv", index=False)
# Remove lines=True so that the JSON output is a list enclosed in square brackets
disease_details_df.to_json("disease_details.json", orient="records", indent=4)

print("\nData saved to 'disease_details.csv' and 'disease_details.json'.")
# Out:
# ===== Extracted Disease Details =====
#                          Disease Name  \
# 0          Avian Influenza (Bird Flu)
# 1        Arbovirus A Chikungunya Type
# 2          Avian Influenza (Bird Flu)
# 3                Bacterial Meningitis
# 4  Bacterial Meningococcal Meningitis
#
#                                                  URL  \
# 0  https://www.webmd.com/cold-and-flu/flu-guide/w...
# 1  https://www.webmd.com/a-to-z-guides/what-is-ch...
# 2  https://www.webmd.com/cold-and-flu/flu-guide/w...
# 3  https://www.webmd.com/children/understanding-m...
# 4  https://www.webmd.com/children/meningococcal-m...
#
#                                             overview  \
# 0  Bird flu, also called avian influenza, is a vi...
# 1
# 2  Bird flu, also called avian influenza, is a vi...
# 3  Meningitis is a rare infection that affects th...
# 4
#
#                                             symptoms  \
# 0  Symptoms of bird flu show up differently in bi...
# 1
# 2  Symptoms of bird flu show up differently in bi...
# 3  Meningitis can cause a rash that starts small ...
# 4  A meningococcal infection can get worse very q...
#
#                                               causes  \
# 0  Bird flu is caused by influenza A viruses. How...
# 1  If you’re going to a place that has an outbrea...
# 2  Bird flu is caused by influenza A viruses. How...
# 3  Anyone can get meningitis, but research shows ...
# 4  Neisseria meningitidis, also called meningococ...
#
#                                            diagnosis  \
# 0  Doctors can’t diagnose bird flu just by your s...
# 1
# 2  Doctors can’t diagnose bird flu just by your s...
# 3  Your doctor will ask about your medical histor...
# 4  If they suspect meningococcal meningitis, doct...
#
#                                            treatment medication  \
# 0  If you see a doctor early in your infection, t...
# 1
# 2  If you see a doctor early in your infection, t...
# 3  Your treatment will depend on the type of meni...
# 4  The treatment for meningococcal meningitis is ...
#
#                                        complications  \
# 0  It’s possible that bird flu may cause further ...
# 1
# 2  It’s possible that bird flu may cause further ...
# 3  Meningitis can cause severe complications in a...
# 4  Meningococcal meningitis can cause death or se...
#
#                                            prognosis  \
# 0
# 1  Most people don't die from the virus. In fact,...
# 2
# 3
# 4
#
#                                           prevention
# 0  Your chances of getting bird flu are very low....
# 1
# 2  Your chances of getting bird flu are very low....
# 3  You may be able to prevent meningitis by avoid...
# 4
#
# ===== Diseases with Invalid or Non-Working Links =====
# ['Coronavirus (COVID-19)', 'Coronavirus (COVID-19)']
#
# Data saved to 'disease_details.csv' and 'disease_details.json'.
